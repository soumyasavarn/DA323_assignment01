# %% [markdown]
# # Script for live recording audio from radio stations

# %% [markdown]
# #### It will take 30 * 30 = 900 secs for creating the entire dataset

# %%
import os
import subprocess
import time
import csv
from datetime import datetime

radio_stations = {
    "BBC_Radio": "http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p",
    "NPR": "http://npr-ice.streamguys1.com/live.mp3",
    "KEXP": "http://live-aacplus-64.kexp.org/kexp64.aac"
}

DURATION = 30  # seconds to record per clip 
NUM_FILES = 35  # number of files to record

DATASET_NAME = "Public_Airwaves"
os.makedirs(DATASET_NAME, exist_ok=True)

METADATA_FILE = os.path.join(DATASET_NAME, "metadata.csv")
with open(METADATA_FILE, mode='w', newline='', encoding='utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(["Station Name", "Filename", "Timestamp", "Duration (s)"])

    file_count = 0

    while file_count < NUM_FILES:
        for station_name, stream_url in radio_stations.items():
            if file_count >= NUM_FILES:
                break
            
            # Prepare metadata
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            filename = f"{station_name}_{timestamp}_{file_count+1}.mp3"
            output_path = os.path.join(DATASET_NAME, filename)
            
            # Record audio from the station
            print(f"\n Now recording from {station_name} for {DURATION} seconds...")
            command = [
                "ffmpeg",
                "-y",                    # overwrite output file if exists
                "-i", stream_url,        # input stream URL
                "-t", str(DURATION),     # recording duration in seconds
                "-acodec", "copy",       # copy the audio codec (no re-encoding)
                output_path
            ]
            try:
                result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
                print(f"Successfully saved recording: {output_path}")
                
                # Log metadata for this recording
                csv_writer.writerow([station_name, filename, timestamp, DURATION])
                file_count += 1
            except Exception as e:
                print(f"Error recording from {station_name}: {e}")
            time.sleep(1)

print("\n Audio recording process completed.")
# Out:
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_101419_1.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_101420_1.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_101447_2.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_101450_2.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_101451_2.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_101518_3.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_101520_3.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_101521_3.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_101547_4.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_101549_4.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_101550_4.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_101616_5.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_101619_5.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_101620_5.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_101646_6.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_101648_6.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_101649_6.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_101716_7.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_101718_7.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_101719_7.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_101745_8.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_101747_8.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_101748_8.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_101815_9.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_101817_9.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_101819_9.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_101845_10.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_101847_10.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_101848_10.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_101915_11.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_101918_11.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_101919_11.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_101945_12.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_101947_12.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_101948_12.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_102014_13.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_102016_13.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_102017_13.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_102043_14.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_102046_14.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_102047_14.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_102114_15.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_102116_15.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_102117_15.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_102145_16.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_102147_16.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_102148_16.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_102214_17.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_102216_17.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_102217_17.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_102243_18.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_102246_18.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_102247_18.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_102312_19.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_102315_19.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_102316_19.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_102342_20.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_102344_20.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_102345_20.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_102411_21.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_102413_21.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_102414_21.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_102440_22.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_102442_22.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_102443_22.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_102509_23.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_102512_23.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_102513_23.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_102538_24.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_102541_24.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_102542_24.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_102608_25.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_102610_25.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_102611_25.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_102637_26.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_102640_26.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_102641_26.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_102706_27.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_102709_27.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_102710_27.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_102736_28.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_102739_28.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_102740_28.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_102806_29.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_102808_29.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_102809_29.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_102836_30.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_102838_30.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_102839_30.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_102907_31.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_102909_31.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_102910_31.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_102936_32.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_102939_32.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_102940_32.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_103006_33.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_103008_33.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_103009_33.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_103035_34.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_103037_34.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_103038_34.mp3
#
#  Now recording from KEXP for 30 seconds...
# Error recording from KEXP: Command '['ffmpeg', '-y', '-i', 'http://live-aacplus-64.kexp.org/kexp64.aac', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/KEXP_20250310_103104_35.mp3']' returned non-zero exit status 1.
#
#  Now recording from BBC_Radio for 30 seconds...
# Error recording from BBC_Radio: Command '['ffmpeg', '-y', '-i', 'http://bbcmedia.ic.llnwd.net/stream/bbcmedia_radio1_mf_p', '-t', '30', '-acodec', 'copy', 'Public_Airwaves/BBC_Radio_20250310_103107_35.mp3']' returned non-zero exit status 1.
#
#  Now recording from NPR for 30 seconds...
# Successfully saved recording: Public_Airwaves/NPR_20250310_103108_35.mp3
#
#  Audio recording process completed.

# %%
import shutil

directory_to_zip = '/kaggle/working/Public_Airwaves'
output_zip_file = '/kaggle/working/Public_Airwaves.zip'

# Create a zip file from the directory
shutil.make_archive(output_zip_file.replace('.zip', ''), 'zip', directory_to_zip)
print(f"Zip file created: {output_zip_file}")
# Out:
# Zip file created: /kaggle/working/Public_Airwaves.zip
